# %%
from matplotlib.colors import ListedColormap

from dissmodel.core import Environment
from dissmodel.geo import vector_grid
from dissmodel.models.ca import GameOfLife
from dissmodel.visualization import Map
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       1 from matplotlib.colors import ListedColormap
#       3 from dissmodel.core import Environment
# ----> 4 from dissmodel.geo import vector_grid
#       5 from dissmodel.models.ca import GameOfLife
#       6 from dissmodel.visualization import Map
#
# File /opt/conda/lib/python3.11/site-packages/dissmodel/geo/__init__.py:4
#       1 # dissmodel/geo/__init__.py
#       2
#       3 # vector substrate
# ----> 4 from .vector.neighborhood       import attach_neighbors
#       5 from .vector.vector_grid       import vector_grid, parse_idx
#       6 from .vector.fill               import fill, FillStrategy
#
# File /opt/conda/lib/python3.11/site-packages/dissmodel/geo/vector/neighborhood.py:8
#       5 from typing import Any, Optional, Protocol, Union
#       7 import geopandas as gpd
# ----> 8 from libpysal.weights import W
#      11 # ---------------------------------------------------------------------------
#      12 # Protocol
#      13 # ---------------------------------------------------------------------------
#      15 class WeightStrategy(Protocol):
#
# File /opt/conda/lib/python3.11/site-packages/libpysal/__init__.py:27
#      24 import contextlib
#      25 from importlib.metadata import PackageNotFoundError, version
# ---> 27 from . import cg, examples, graph, io, weights
#      29 with contextlib.suppress(PackageNotFoundError):
#      30     __version__ = version("libpysal")
#
# File /opt/conda/lib/python3.11/site-packages/libpysal/examples/__init__.py:13
#       9 from typing import Union
#      11 import pandas as pd
# ---> 13 from .base import Example, example_manager
#      14 from .builtin import LocalExample
#      15 from .builtin import datasets as builtin_datasets
#
# File /opt/conda/lib/python3.11/site-packages/libpysal/examples/base.py:19
#      16 from bs4 import BeautifulSoup
#      17 from platformdirs import user_data_dir
# ---> 19 from ..io import open as ps_open
#      22 def get_data_home():
#      23     """Return the path of the ``libpysal`` data directory. This folder is platform
#      24     specific. If the folder does not already exist, it is automatically created.
#      25
#    (...)
#      29         The system path where the data is/will be stored.
#      30     """
#
# File /opt/conda/lib/python3.11/site-packages/libpysal/io/__init__.py:2
#       1 from . import fileio
# ----> 2 from .iohandlers import *
#       3 from .tables import *
#       4 from .util import *
#
# File /opt/conda/lib/python3.11/site-packages/libpysal/io/iohandlers/__init__.py:3
#       1 import warnings
# ----> 3 from . import (
#       4     arcgis_dbf,
#       5     arcgis_swm,
#       6     arcgis_txt,
#       7     csvWrapper,
#       8     dat,
#       9     gal,
#      10     geobugs_txt,
#      11     geoda_txt,
#      12     gwt,
#      13     mat,
#      14     mtx,
#      15     pyDbfIO,
#      16     pyShpIO,
#      17     stata_txt,
#      18     wk1,
#      19     wkt,
#      20 )
#      22 try:
#      23     from . import db
#
# File /opt/conda/lib/python3.11/site-packages/libpysal/io/iohandlers/arcgis_dbf.py:3
#       1 # ruff: noqa: N802, N803, N806, N815
# ----> 3 from ...weights.util import remap_ids
#       4 from ...weights.weights import W
#       5 from .. import fileio
#
# File /opt/conda/lib/python3.11/site-packages/libpysal/weights/__init__.py:10
#       8 from .spatial_lag import *
#       9 from .raster import *
# ---> 10 from .gabriel import Gabriel, Delaunay, Relative_Neighborhood
#
# File /opt/conda/lib/python3.11/site-packages/libpysal/weights/gabriel.py:11
#       8 from libpysal.weights import WSP, W
#      10 try:
# ---> 11     from numba import njit
#      12 except ModuleNotFoundError:
#      13     from libpysal.common import jit as njit
#
# File /opt/conda/lib/python3.11/site-packages/numba/__init__.py:55
#      50             msg = ("Numba requires SciPy version 1.0 or greater. Got SciPy "
#      51                    f"{scipy.__version__}.")
#      52             raise ImportError(msg)
# ---> 55 _ensure_critical_deps()
#      56 # END DO NOT MOVE
#      57 # ---------------------- WARNING WARNING WARNING ----------------------------
#      60 from ._version import get_versions
#
# File /opt/conda/lib/python3.11/site-packages/numba/__init__.py:42, in _ensure_critical_deps()
#      40     raise ImportError(msg)
#      41 elif numpy_version > (1, 24):
# ---> 42     raise ImportError("Numba needs NumPy 1.24 or less")
#      43 try:
#      44     import scipy
#
# ImportError: Numba needs NumPy 1.24 or less

# %%
gdf = vector_grid(dimension=(20, 20), resolution=1, attrs={"state": 0})
